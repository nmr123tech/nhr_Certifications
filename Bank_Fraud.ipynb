# %% [markdown]
# <a href="https://colab.research.google.com/github/nmr123tech/nhr_Certifications/blob/main/Bank_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 73372  55105  1.104021 -1.123835  1.008939 -0.460960 -1.502758  0.021138
# 73373  55105  1.182898 -0.283273  1.123494  0.066948 -1.283276 -0.900451
# 73374  55106  1.168124 -0.122507  1.251822  0.860341 -1.020137 -0.277310
# 73375  55106 -0.339385 -2.095670  0.271543 -3.066469  0.484794  3.870704
# 73376  55107 -1.020407  0.160171  0.152264 -0.093406 -0.978017  0.074549
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 73372 -1.055043  0.095135 -0.175413  ...  0.405906  1.054006 -0.174455
# 73373 -0.441870 -0.150647  0.784691  ...  0.082278  0.491790 -0.025468
# 73374 -0.557856  0.023732  0.802378  ... -0.077921 -0.005984  0.014309
# 73375 -2.069399  0.184347 -1.615958  ...  0.964115 -0.266112 -0.993763
# 73376  1.610152  0.117407 -0.948643  ...  0.109380 -0.400171  0.835422
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73377 entries, 0 to 73376
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    73377 non-null  int64
#  1   V1      73377 non-null  float64
#  2   V2      73377 non-null  float64
#  3   V3      73377 non-null  float64
#  4   V4      73377 non-null  float64
#  5   V5      73377 non-null  float64
#  6   V6      73377 non-null  float64
#  7   V7      73377 non-null  float64
#  8   V8      73377 non-null  float64
#  9   V9      73377 non-null  float64
#  10  V10     73377 non-null  float64
#  11  V11     73377 non-null  float64
#  12  V12     73377 non-null  float64
#  13  V13     73377 non-null  float64
#  14  V14     73377 non-null  float64
#  15  V15     73377 non-null  float64
#  16  V16     73377 non-null  float64
#  17  V17     73377 non-null  float64
#  18  V18     73377 non-null  float64
#  19  V19     73377 non-null  float64
# ...

# %%
# checking the number of missing values in each coloumn
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of lagit transactions and fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    73198
# 1.0      178
# Name: Class, dtype: int64

# %% [markdown]
# this data is highly imbalanced

# %% [markdown]
# 0 = normal transaction

# %% [markdown]
# 1 = fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print (legit.shape)
print (fraud.shape)
# Out:
# (73198, 31)
# (178, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    73198.000000
# mean        97.324727
# std        270.324183
# min          0.000000
# 25%          7.680000
# 50%         26.675000
# 75%         88.947500
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe ()
# Out:
# count     178.000000
# mean       95.191461
# std       218.660540
# min         0.000000
# 25%         1.000000
# 50%         7.595000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    35597.170893 -0.237300 -0.038920  0.702672  0.155577 -0.260766
# 1.0    30706.921348 -6.783789  4.890766 -9.107666  5.286608 -5.047343
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.103663 -0.096812  0.047751  0.017704  ...  0.044057 -0.030721
# 1.0   -2.085865 -7.104280  3.332048 -3.159344  ...  0.420153  0.813143
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106049 -0.038141  0.006549  0.135145  0.023827  0.000959  0.002925
# 1.0   -0.191093 -0.236559 -0.071391  0.249935  0.106447  0.567944  0.044848
#
#           Amount
# Class
# 0.0    97.324727
# 1.0    95.191461
#
# [2 rows x 30 columns]

# %% [markdown]
# build a sample dataset containing similar distributions of normal transactions and fraudulent transactions

# %% [markdown]
# number of fraudulent transactions=492

# %%
legit_sample = legit.sample (n=492)

# %% [markdown]
# concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 71219  54212 -2.001850  0.428443  0.903929 -0.214331 -0.134220 -0.555604
# 59351  48804 -1.544423  1.017319  0.420656  1.024278 -0.046795 -0.828945
# 33963  37455 -0.373947  1.137653  0.303088  1.142335  0.318012  0.331447
# 68404  52978  1.143589 -0.847333  0.456730 -0.814882 -0.816739  0.240972
# 859      651 -1.019264  1.099495  1.444093 -0.631522  0.132875 -0.395445
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 71219 -0.122896  0.121556  0.088052  ... -0.143430 -0.008985 -0.111116
# 59351 -0.011885  0.656100 -1.012395  ...  0.257691  0.322179 -0.278867
# 33963  0.222541  0.215863  0.269774  ... -0.008139  0.492025  0.069464
# 68404 -0.765175  0.253008 -0.940481  ...  0.044403 -0.142030  0.130297
# 859    0.588347  0.196130 -0.250792  ... -0.123260 -0.326892  0.069919
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
# 72757  54846 -2.986466 -0.000891  0.605887  0.338338  0.685448 -1.581954
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 69498 -2.582865  0.643230 -1.191233  ...  0.594623  0.372144 -0.310456
# 69980 -2.340991  0.713004 -1.416265  ...  0.383180 -0.213952 -0.336640
# 70141 -2.355254  0.854659 -1.281243  ...  0.679176  0.731907  0.333045
# 70589 -3.039520 -1.634233 -0.594809  ... -0.723326  0.501222 -0.696892
# 72757  0.504206 -0.233403  0.636768  ... -0.875146 -0.509849  1.313918
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    178
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    35983.089431 -0.212163 -0.004053  0.668688  0.237166 -0.290347
# 1.0    30706.921348 -6.783789  4.890766 -9.107666  5.286608 -5.047343
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.083439 -0.086651  0.107436  0.020857  ...  0.055046 -0.020176
# 1.0   -2.085865 -7.104280  3.332048 -3.159344  ...  0.420153  0.813143
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.063208 -0.032160 -0.013749  0.153761  0.015830 -0.020009  0.017084
# 1.0   -0.191093 -0.236559 -0.071391  0.249935  0.106447  0.567944  0.044848
#
#           Amount
# Class
# 0.0    95.478476
# 1.0    95.191461
#
# [2 rows x 30 columns]

# %% [markdown]
# splitting the data into features and targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 71219  54212 -2.001850  0.428443  0.903929 -0.214331 -0.134220 -0.555604
# 59351  48804 -1.544423  1.017319  0.420656  1.024278 -0.046795 -0.828945
# 33963  37455 -0.373947  1.137653  0.303088  1.142335  0.318012  0.331447
# 68404  52978  1.143589 -0.847333  0.456730 -0.814882 -0.816739  0.240972
# 859      651 -1.019264  1.099495  1.444093 -0.631522  0.132875 -0.395445
# ...      ...       ...       ...       ...       ...       ...       ...
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
# 72757  54846 -2.986466 -0.000891  0.605887  0.338338  0.685448 -1.581954
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 71219    0.0
# 59351    0.0
# 33963    0.0
# 68404    0.0
# 859      0.0
#         ...
# 69498    1.0
# 69980    1.0
# 70141    1.0
# 70589    1.0
# 72757    1.0
# Name: Class, Length: 670, dtype: float64

# %% [markdown]
# split the data into training data and texting data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (670, 30) (536, 30) (134, 30)

# %% [markdown]
# model training

# %% [markdown]
# logistic regression

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# model evaluation

# %% [markdown]
# accuracy score

# %%
# accuracy on trainimg data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data:',training_data_accuracy)
# Out:
# Accuracy on Training data: 0.9757462686567164

# %%
# accuracy on test data
X_test_prediction =model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data:',test_data_accuracy)
# Out:
# Accuracy score on Test Data: 0.9552238805970149
